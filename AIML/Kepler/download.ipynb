# %%
import os
import re
import lightkurve as lk
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

# ------------------------------
# Parameters
# ------------------------------
NUM_WORKERS = 12
OUTPUT_DIR = "output_lightcurves"

# ------------------------------
# Load dataset (ALL KOIs)
# ------------------------------
df = pd.read_csv("kepler_core.csv")   # update path
all_kepids = df["kepid"].unique()
print(f"🔍 Found {len(all_kepids)} total Kepler IDs in dataset")

# ------------------------------
# Output folder
# ------------------------------
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ------------------------------
# Track already downloaded
# ------------------------------
existing_files = os.listdir(OUTPUT_DIR)
already_downloaded = {
    int(re.search(r"KIC(\d+)", f).group(1))
    for f in existing_files if "KIC" in f
}
remaining_kepids = [kid for kid in all_kepids if kid not in already_downloaded]

print(f"✅ {len(already_downloaded)} already downloaded")
print(f"⬇️ {len(remaining_kepids)} left to download")

# ------------------------------
# Download + Merge function
# ------------------------------
def download_lightcurve_merged(kepid, idx):
    try:
        search = lk.search_lightcurve(f"KIC {kepid}", mission="Kepler")
        if len(search) == 0:
            return f"❌ No data for KIC {kepid}"

        lcs = search.download_all()
        if lcs is None or len(lcs) == 0:
            return f"⚠️ Failed for KIC {kepid}"

        # Merge all available sectors into one DataFrame
        merged_df = pd.concat([lc.to_pandas() for lc in lcs if lc is not None], ignore_index=True)

        # Save single merged CSV
        outpath = os.path.join(OUTPUT_DIR, f"lightcurve_{idx}_KIC{kepid}.csv")
        merged_df.to_csv(outpath, index=False)

        return f"✅ Saved merged lightcurve ({len(merged_df)} rows) for KIC {kepid}"
    except Exception as e:
        return f"❌ Error for KIC {kepid}: {str(e)}"

# ------------------------------
# Run parallel downloads
# ------------------------------
results = []
if len(remaining_kepids) > 0:
    with ThreadPoolExecutor(max_workers=NUM_WORKERS) as executor:
        futures = {
            executor.submit(download_lightcurve_merged, kepid, i): kepid
            for i, kepid in enumerate(remaining_kepids, start=1)
        }
        for future in tqdm(as_completed(futures), total=len(futures), desc="Downloading ALL KOIs"):
            results.append(future.result())

# ------------------------------
# Summary
# ------------------------------
print("\nDownload Summary:")
for r in results[:30]:  # show first 30 logs
    print(r)

print(f"\n✅ Completed: {sum('Saved' in r for r in results)}")
print(f"❌ Failed: {sum('❌' in r for r in results)}")
# Out:
# c:\ProgramData\miniconda3\envs\GPU\lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(
# 🔍 Found 8214 total Kepler IDs in dataset
# ✅ 1752 already downloaded
# ⬇️ 6462 left to download
# Downloading ALL KOIs:   0%|          | 0/6462 [00:00<?, ?it/s]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 1/6462 [00:13<23:37:18, 13.16s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 2/6462 [00:15<11:53:52,  6.63s/it]WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (498240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (498240) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 3/6462 [00:41<28:16:16, 15.76s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 4/6462 [00:51<24:08:15, 13.46s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 5/6462 [00:53<16:19:49,  9.10s/it]WARNING: File may have been truncated: actual file length (113072) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (113072) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 6/6462 [00:53<10:51:18,  6.05s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (483840) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (483840) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 7/6462 [00:53<7:26:54,  4.15s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 9/6462 [00:54<3:59:00,  2.22s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (348480) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (348480) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 10/6462 [00:58<5:00:49,  2.80s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 11/6462 [01:00<4:45:03,  2.65s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 13/6462 [01:01<2:38:06,  1.47s/it]WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 14/6462 [01:02<2:22:00,  1.32s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 15/6462 [01:05<3:10:55,  1.78s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 16/6462 [01:06<3:05:13,  1.72s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 17/6462 [01:07<2:39:48,  1.49s/it]WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (457920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (131072) is smaller than the expected size (457920) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 18/6462 [01:09<2:40:42,  1.50s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 20/6462 [01:11<2:35:06,  1.44s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 21/6462 [01:13<2:31:55,  1.42s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 23/6462 [01:14<2:01:23,  1.13s/it]WARNING: File may have been truncated: actual file length (3538944) is smaller than the expected size (4475520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (3538944) is smaller than the expected size (4475520) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 24/6462 [01:23<5:32:33,  3.10s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4314240) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4314240) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 29/6462 [01:40<3:40:46,  2.06s/it] WARNING: File may have been truncated: actual file length (196608) is smaller than the expected size (463680) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (196608) is smaller than the expected size (463680) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 31/6462 [01:47<4:15:21,  2.38s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (457920) [astropy.io.fits.file]
# Downloading ALL KOIs:   0%|          | 32/6462 [01:47<3:30:33,  1.96s/it]WARNING: UnitsWarning: 'pixels' did not parse as fits unit: At col 0, Unit 'pixels' not supported by the FITS standard. Did you mean pixel? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (178560) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (178560) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 52/6462 [02:52<3:10:51,  1.79s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 53/6462 [02:54<3:13:07,  1.81s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 58/6462 [03:57<16:07:07,  9.06s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4432320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 63/6462 [04:14<10:29:14,  5.90s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4475520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4475520) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 66/6462 [04:22<6:37:22,  3.73s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 73/6462 [04:33<4:59:09,  2.81s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|          | 74/6462 [04:34<3:53:16,  2.19s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   1%|▏         | 87/6462 [06:04<4:38:08,  2.62s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   2%|▏         | 107/6462 [08:33<9:47:10,  5.54s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4003200) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4003200) [astropy.io.fits.file]
# Downloading ALL KOIs:   2%|▏         | 127/6462 [08:52<48:11,  2.19it/s]  WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   2%|▏         | 139/6462 [10:32<2:52:22,  1.64s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (69120) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (69120) [astropy.io.fits.file]
# Downloading ALL KOIs:   2%|▏         | 140/6462 [10:32<2:13:13,  1.26s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   2%|▏         | 154/6462 [12:00<4:16:12,  2.44s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   3%|▎         | 173/6462 [12:28<4:29:14,  2.57s/it]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   3%|▎         | 182/6462 [12:32<1:06:47,  1.57it/s]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   3%|▎         | 197/6462 [13:56<2:39:11,  1.52s/it] WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4475520) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (4475520) [astropy.io.fits.file]
# Downloading ALL KOIs:   3%|▎         | 203/6462 [13:59<1:00:19,  1.73it/s]WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (184320) [astropy.io.fits.file]
# Downloading ALL KOIs:   3%|▎         | 205/6462 [14:06<3:38:24,  2.09s/it]
